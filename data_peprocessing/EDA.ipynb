# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd


# path = "/content/drive/Shareddrives/2022 디지털산업혁신 빅데이터 플랫폼 아이디어 경진대회/dataset/"

# %% [markdown]
# # **RND 실적**

# %% [markdown]
# # **국내시장동향**

# %% [markdown]
# # **글로벌시장동향**

# %% [markdown]
# # **기술경쟁력분석**

# %% [markdown]
# # **기술기반보유역량**

# %% [markdown]
# # **기업경쟁력정보**

# %%
df = pd.read_csv('/content/drive/Shareddrives/2022 디지털산업혁신 빅데이터 플랫폼 아이디어 경진대회/dataset/기업경쟁력정보/csv_tb_bs_compete_i.csv', encoding = 'cp949')
df

# %%
df['동종업계성장성점수'].isnull().sum()

# %%
df['동종업계성장성점수'].isnull().sum()

# %% [markdown]
# # **기업정보요약**

# %% [markdown]
# # **마케팅보유역량**

# %% [markdown]
# # **비즈니스모델정보**

# %%
df = pd.read_csv('/content/drive/Shareddrives/2022 디지털산업혁신 빅데이터 플랫폼 아이디어 경진대회/dataset/비즈니스모델정보/csv_tb_bs_bm_i.csv', encoding = 'cp949')
df

# %%
# df['안정성수준등급'].isnull().sum()
df['안정성수준등급'].value_counts()

# %% [markdown]
# # **사업화보유역량**

# %%
df = pd.read_csv('/content/drive/Shareddrives/2022 디지털산업혁신 빅데이터 플랫폼 아이디어 경진대회/dataset/사업화보유역량/csv_tb_bs_biz_i.csv', encoding='cp949')
df

# %%
df['사업자등록번호'].nunique()

# %%
df['사업화기반구축수준등급'].value_counts()

# %%
df['사업화기반구축수준점수'].value_counts()

# %% [markdown]
# # **산업분류코드**

# %%
df = pd.read_csv('/content/drive/Shareddrives/2022 디지털산업혁신 빅데이터 플랫폼 아이디어 경진대회/dataset/산업분류코드/csv_tb_bs_code_c.csv', encoding='cp949')
df

# %%
df['항목코드명'].value

# %% [markdown]
# # **산업통계정보**

# %% [markdown]
# # **인적자원정보**

# %% [markdown]
# # **특허통계정보**

# %% [markdown]
# # **경영진 정보**

# %% [markdown]
# # **국가R&D과제**

# %% [markdown]
# # **국가R&D성과**

# %% [markdown]
# # **국가R&D연구보고서**

# %% [markdown]
# # **기업정보상세**

# %%
df = pd.read_csv('/content/drive/Shareddrives/2022 디지털산업혁신 빅데이터 플랫폼 아이디어 경진대회/dataset/기업성장_16종/기업정보상세.csv')
df.head()

# %%
df.shape

# %%
df['데이터수집일자'].value_counts().sum()

# %%
df.columns

# %%
df.shape

# %%
df['휴폐업구분'].value_counts()

# %%
df['산업분류코드설명']

# %%
df[df['산업분류코드'] == 58222]['휴폐업구분'].count()

# %%
target = [58211, 58212, 58219, 58221, 58222, 62010, 62021, 
          62090, 63111, 63112, 63120, 63910, 63991, 63999]

com_num = 0
com_out_num = 0

for i in target:
  com_num += len(df[df['산업분류코드'] == i])
  com_out_num += df[df['산업분류코드'] == i]['휴폐업구분'].count()

print(com_num)
print(com_out_num)
print(com_out_num/com_num)

# %% [markdown]
# # **기업정보요약**

# %% [markdown]
# # **디자인권정보**

# %% [markdown]
# # **상표권정보**

# %% [markdown]
# # **신용등급정보**

# %% [markdown]
# # **실용신안정보**

# %% [markdown]
# # **온라인뉴스**

# %% [markdown]
# # **재무제표정보**

# %%
df = pd.read_csv('/content/drive/Shareddrives/2022 디지털산업혁신 빅데이터 플랫폼 아이디어 경진대회/dataset/기업성장_16종/재무제표정보.csv')
df

# %% [markdown]
# # **취업포탈리뷰**

# %%
df = pd.read_csv('/content/drive/Shareddrives/2022 디지털산업혁신 빅데이터 플랫폼 아이디어 경진대회/dataset/기업성장_16종/취업포탈리뷰.csv')
df

# %%
df.columns

# %%
df['사업자등록번호'].nunique()

# %%
df['사업자등록번호'].issnull()

# %% [markdown]
# # **특허정보상세**

# %% [markdown]
# # **특허정보요약**

# %% [markdown]
# # **패밀리특허정보**

# %%
# df = pd.read_csv(path + '경영진정보.csv')
# df = pd.read_csv(path + '국가R&D과제.csv')
# df = pd.read_csv(path + '국가R&D성과.csv')
# df = pd.read_csv(path + '국가R&D연구보고서.csv')
df = pd.read_csv(path + '기업정보상세.csv')
# df = pd.read_csv(path + '기업정보요약.csv')
# df = pd.read_csv(path + '디자인권정보.csv')
# df = pd.read_csv(path + '상표권정보.csv')
# df = pd.read_csv(path + '신용등급정보.csv')
# df = pd.read_csv(path + '실용신안정보.csv')
# df = pd.read_csv(path + '온라인뉴스.csv')
# df = pd.read_csv(path + '재무제표정보.csv')
# df = pd.read_csv(path + '취업포탈리뷰.csv')
# df = pd.read_csv(path + '특허정보상세.csv')
# df = pd.read_csv(path + '특허정보요약.csv')
# df = pd.read_csv(path + '패밀리특허정보.csv')


df.head()

# %%
df.columns

# %%
df['사업자등록번호'].nunique()
